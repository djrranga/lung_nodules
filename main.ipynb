# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel('data/43856_2023_388_MOESM3_ESM.xlsx')

# Assuming you have a dataframe named df
train, temp = train_test_split(df, test_size=0.3, random_state=42)
validation, test = train_test_split(temp, test_size=0.5, random_state=42)

print("Training set size:", len(train))
print("Validation set size:", len(validation))
print("Test set size:", len(test))
# Out:
# Training set size: 7000
# Validation set size: 1500
# Test set size: 1500

# %%
train.head(10)
# Out:
#         FPrate  Sensitivity[Mean]  Sensitivity_1  Sensitivity_2  \
# 9069  7.261739           0.988531       0.988304       0.988636
# 2603  2.128838           0.963273       0.959064       0.965909
# 7738  6.205152           0.988531       0.988304       0.988636
# 1579  1.315957           0.932275       0.923977       0.943182
# 5058  4.077689           0.978165       0.970760       0.982955
# 5753  4.629400           0.983899       0.976608       0.988636
# 3548  2.879007           0.971294       0.964912       0.977273
# 409   0.387176           0.850861       0.847953       0.875000
# 4097  3.314819           0.974743       0.970760       0.977273
# 6461  5.191432           0.986212       0.982456       0.988636
#
#       Sensitivity_3  Sensitivity_4  Sensitivity_5
# 9069       0.988506       0.988636       0.988571
# 2603       0.959770       0.965909       0.965714
# 7738       0.988506       0.988636       0.988571
# 1579       0.931034       0.943182       0.920000
# 5058       0.977011       0.982955       0.977143
# 5753       0.982759       0.988636       0.982857
# 3548       0.971264       0.971591       0.971429
# 409        0.844828       0.857955       0.828571
# 4097       0.971264       0.977273       0.977143
# 6461       0.982759       0.988636       0.988571

# %%
validation.head(10)
# Out:
#         FPrate  Sensitivity[Mean]  Sensitivity_1  Sensitivity_2  \
# 8127  6.513951           0.988531       0.988304       0.988636
# 4321  3.492637           0.974743       0.970760       0.977273
# 450   0.419723           0.868111       0.871345       0.880682
# 5798  4.665123           0.983899       0.976608       0.988636
# 5181  4.175330           0.978165       0.970760       0.982955
# 3997  3.235436           0.974743       0.970760       0.977273
# 3038  2.474154           0.965559       0.959064       0.971591
# 2122  1.747006           0.948316       0.935673       0.960227
# 3063  2.493999           0.966696       0.959064       0.971591
# 8026  6.433775           0.988531       0.988304       0.988636
#
#       Sensitivity_3  Sensitivity_4  Sensitivity_5
# 8127       0.988506       0.988636       0.988571
# 4321       0.971264       0.977273       0.977143
# 450        0.867816       0.875000       0.845714
# 5798       0.982759       0.988636       0.982857
# 5181       0.977011       0.982955       0.977143
# 3997       0.971264       0.977273       0.977143
# 3038       0.965517       0.965909       0.965714
# 2122       0.948276       0.954545       0.942857
# 3063       0.965517       0.971591       0.965714
# 8026       0.988506       0.988636       0.988571

# %%
test.head(10)
# Out:
#         FPrate  Sensitivity[Mean]  Sensitivity_1  Sensitivity_2  \
# 2697  2.203458           0.963273       0.959064       0.965909
# 6871  5.516902           0.987361       0.982456       0.988636
# 3487  2.830583           0.970144       0.964912       0.977273
# 92    0.135532           0.766012       0.771930       0.789773
# 9537  7.633251           0.988531       0.988304       0.988636
# 3205  2.606723           0.966696       0.959064       0.971591
# 6641  5.334321           0.986212       0.982456       0.988636
# 8909  7.134726           0.988531       0.988304       0.988636
# 2884  2.351904           0.963273       0.959064       0.965909
# 7173  5.756638           0.988531       0.988304       0.988636
#
#       Sensitivity_3  Sensitivity_4  Sensitivity_5
# 2697       0.959770       0.965909       0.965714
# 6871       0.988506       0.988636       0.988571
# 3487       0.965517       0.971591       0.971429
# 92         0.741379       0.778409       0.748571
# 9537       0.988506       0.988636       0.988571
# 3205       0.965517       0.971591       0.965714
# 6641       0.982759       0.988636       0.988571
# 8909       0.988506       0.988636       0.988571
# 2884       0.959770       0.965909       0.965714
# 7173       0.988506       0.988636       0.988571
